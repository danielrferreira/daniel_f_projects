# %% [markdown]
# # Spotify Exploratory Analysis using EDA Aid

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import importlib
from sklearn.ensemble import RandomForestClassifier
import eda_aid as ea

# %%
path = '/Users/danielferreira/Documents/git/daniel_f_projects/sample_codes/EA_AID/data_sources/'
file =  'billboard_24years_lyrics_spotify.csv'
df = pd.read_csv(path+file)
df['ranking_1'] = df['ranking']==1

# %%
ed = ea.eda_aid(df)
# Out:
# EDA Aid initialized with 3397 rows and 27 columns:
#  - Numeric: 15
#  - Object: 11
#  - Boolean: 1

# %%
ed.columns_df()
# Out:
#                      type  missing_count  missing_proportions  \
# name
# ranking           numeric              0                0.000
# year              numeric              0                0.000
# danceability      numeric           2911                0.857
# energy            numeric           2911                0.857
# key               numeric           2911                0.857
# loudness          numeric           2911                0.857
# mode              numeric           2911                0.857
# speechiness       numeric           2911                0.857
# acousticness      numeric           2911                0.857
# instrumentalness  numeric           2911                0.857
# liveness          numeric           2911                0.857
# valence           numeric           2911                0.857
# tempo             numeric           2911                0.857
# duration_ms       numeric           2911                0.857
# time_signature    numeric           2911                0.857
# song               object              0                0.000
# band_singer        object              0                0.000
# songurl            object              0                0.000
# titletext          object              0                0.000
# url                object              0                0.000
# lyrics             object              0                0.000
# uri                object              0                0.000
# type               object           2911                0.857
# id                 object           2911                0.857
# track_href         object           2911                0.857
# analysis_url       object           2911                0.857
# ranking_1         boolean              0                0.000
#
#                   non_missing_count
# name
# ranking                        3397
# year                           3397
# danceability                    486
# energy                          486
# key                             486
# loudness                        486
# mode                            486
# speechiness                     486
# acousticness                    486
# instrumentalness                486
# liveness                        486
# valence                         486
# tempo                           486
# duration_ms                     486
# time_signature                  486
# song                           3397
# band_singer                    3397
# songurl                        3397
# titletext                      3397
# url                            3397
# lyrics                         3397
# uri                            3397
# type                            486
# id                              486
# track_href                      486
# analysis_url                    486
# ranking_1                      3397

# %%
ed.missingness_chi_whitin()

# %%
ed.missingness_association()

# %%
importlib.reload(ea)
ed = ea.eda_aid(df)
ed.ln_analysis('ranking_1')
# Out:
# EDA Aid initialized with 3397 rows and 27 columns:
#  - Numeric: 15
#  - Object: 11
#  - Boolean: 1
# ----------------------------------------------------------------------------------------------------
# ranking_1 vs ranking -> rem_ol=False
# ----------------------------------------------------------------------------------------------------
# 0 = (0.901, 10.9]
# 1 = (10.9, 20.8]
# 2 = (20.8, 30.7]
# 3 = (30.7, 40.6]
# 4 = (40.6, 50.5]
# 5 = (50.5, 60.4]
# 6 = (60.4, 70.3]
# 7 = (70.3, 80.2]
# 8 = (80.2, 90.1]
# 9 = (90.1, 100.0]
# ----------------------------------------------------------------------------------------------------
# ranking_1 vs year -> rem_ol=False
# ----------------------------------------------------------------------------------------------------
# 0 = (1999.977, 2002.3]
# 1 = (2002.3, 2004.6]
# 2 = (2004.6, 2006.9]
# 3 = (2006.9, 2009.2]
# 4 = (2009.2, 2011.5]
# 5 = (2011.5, 2013.8]
# 6 = (2013.8, 2016.1]
# 7 = (2016.1, 2018.4]
# 8 = (2018.4, 2020.7]
# 9 = (2020.7, 2023.0]

# %%
ed.numeric_list
# Out:
# ['ranking',
#  'year',
#  'danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature']

# %%
ed.categorical_list
# Out:
# ['song',
#  'band_singer',
#  'songurl',
#  'titletext',
#  'url',
#  'lyrics',
#  'uri',
#  'type',
#  'id',
#  'track_href',
#  'analysis_url']

# %%
ed.eda_quant_uni()

# %%
cols = ['ranking', 'year', 'danceability', 'energy', 'loudness', 
       'speechiness', 'acousticness', 'liveness',
       'valence', 'tempo', 'duration_ms']
ed.eda_quant_uni(cols)

# %%
cols = ['ranking', 'year', 'danceability', 'energy', 'loudness', 
       'speechiness', 'acousticness', 'liveness',
       'valence', 'tempo', 'duration_ms']
ed.eda_quant_uni(cols, type='violin')

# %%
ed.eda_quant_uni(cols, type='box')
