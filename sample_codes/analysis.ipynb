# %% [markdown]
# # Quick Cluster Analysis of 2024 MLB batters

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import functions as df_f
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import numpy as np

# %%
bat = pd.read_csv('data_sources/batting_2021_2024.csv', index_col='name')
bat_2024 = bat[bat['year']==2024][['player_age', 'ab', 'on_base_plus_slg', 'exit_velocity_avg', 'sprint_speed']]
bat_2024.head()
# Out:
#                    player_age   ab  on_base_plus_slg  exit_velocity_avg  \
# name
# Peralta, David             36  236             0.750               88.1
# Blackmon, Charlie          37  449             0.741               84.8
# Maldonado, Martín          37  135             0.404               88.0
# Solano, Donovan            36  283             0.760               87.3
# McCutchen, Andrew          37  448             0.739               88.5
#
#                    sprint_speed
# name
# Peralta, David             26.9
# Blackmon, Charlie          27.4
# Maldonado, Martín          23.1
# Solano, Donovan            25.5
# McCutchen, Andrew          26.8

# %% [markdown]
# Missings

# %%
bat_2024.isna().sum()
# Out:
# player_age            0
# ab                    0
# on_base_plus_slg      0
# exit_velocity_avg     0
# sprint_speed         14
# dtype: int64

# %% [markdown]
# I will remove the 14 players for this case

# %%
bat_2024_no_miss = bat_2024[~bat_2024['sprint_speed'].isna()].copy()

# %%
bat_2024_no_miss.isna().sum()
# Out:
# player_age           0
# ab                   0
# on_base_plus_slg     0
# exit_velocity_avg    0
# sprint_speed         0
# dtype: int64

# %% [markdown]
# Some correlations from the inputs

# %%
print('Pearson Correlation')
plt.figure(figsize=(8,4))
sns.heatmap(bat_2024_no_miss.corr(),annot=True, cmap='coolwarm')
plt.show()
print('Spearman Correlation')
plt.figure(figsize=(8,4))
sns.heatmap(bat_2024_no_miss.corr(method='spearman'),annot=True, cmap='coolwarm')
plt.show()
# Out:
# Pearson Correlation
# Spearman Correlation

# %% [markdown]
# Histplots

# %%
col = ['player_age','ab','on_base_plus_slg','exit_velocity_avg', 'sprint_speed']
df_f.hist_plots(data=bat_2024_no_miss ,columns=col)

# %% [markdown]
# Because the euclidian distances can be more influenced by variables with higher scale, we need to rescale the data. Some people like to rescale the data using sklearn methods, like MinMaxScaler or StandardScaler:

# %%
scaler = StandardScaler()
data_standardized = scaler.fit_transform(bat_2024_no_miss)
df = pd.DataFrame(data_standardized)

# %%
wcss = []  # Within-cluster sum of squares
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', n_init=100) #n_init is the number of different initial seeds, reduce if your data is large.
    kmeans.fit(data_standardized)
    wcss.append(kmeans.inertia_)

# Plot the elbow method
plt.plot(range(1, 11), wcss)
plt.title('Within-cluster sum of squares by k')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')  # Within-cluster sum of squares
plt.show()

# %% [markdown]
# No clear number of clusters appear, let's see what PCA shows about how many relevant dimensions we have

# %%
pca = PCA()
data_pca = pca.fit_transform(data_standardized)
plt.scatter(data_pca[:, 0], data_pca[:, 1])
plt.title('2D PCA Projection')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()
explained_variance_ratio = pca.explained_variance_ratio_
cumulative_explained_variance = np.cumsum(explained_variance_ratio)
plt.figure(figsize=(10, 6))
plt.bar(range(1, len(explained_variance_ratio) + 1), explained_variance_ratio, align='center',label='Individual explained variance')
plt.step(range(1, len(explained_variance_ratio) + 1), cumulative_explained_variance, where='mid',label='Cumulative explained variance')
plt.xlabel('Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.title('Explained Variance Ratio by Principal Components')
plt.legend()

# %% [markdown]
# I will use 4 groups, the previous analysis showed that there is no clear optimal k

# %%
kmeans_final = KMeans(n_clusters=4, init='k-means++', n_init=200)
kmeans_final.fit(df)
df['Cluster'] = kmeans_final.labels_
plt.scatter(data_pca[:, 0], data_pca[:, 1],c=df['Cluster'], cmap='viridis')
plt.title('Clusters by 2D PCs')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.show()

# %% [markdown]
# Frequency of each group

# %%
cluster_frequency = df['Cluster'].value_counts()
labels = cluster_frequency.index
sizes = cluster_frequency.values
plt.pie(sizes, labels=labels, autopct=lambda p: '{:.1f}%'.format(p))
plt.title('Cluster Frequency')
plt.show()

# %% [markdown]
# Profiling of Clusters. We first need to get the final clusters to the original data (before standardization)

# %%
bat_2024_no_miss['Cluster'] = kmeans_final.labels_

# %% [markdown]
# Violin Plots of each original input and final cluster

# %%
df_f.violin_plots(bat_2024_no_miss, 'Cluster', ['player_age', 'ab', 'on_base_plus_slg', 'exit_velocity_avg', 'sprint_speed'] , n_cols = 2)

# %% [markdown]
# Quick look at group 3, which seems to be the OPS beasts:

# %%
bat_2024_no_miss[bat_2024_no_miss['Cluster']==3].sort_values('on_base_plus_slg', ascending=False)
# Out:
#                     player_age   ab  on_base_plus_slg  exit_velocity_avg  \
# name
# Judge, Aaron                32  559             1.159               96.2
# Ohtani, Shohei              29  636             1.036               95.8
# Tucker, Kyle                27  277             0.993               91.1
# Soto, Juan                  25  576             0.988               94.2
# Witt Jr., Bobby             24  636             0.977               92.7
# ...                        ...  ...               ...                ...
# Bailey, Patrick             25  401             0.637               91.3
# Morel, Christopher          25  535             0.634               89.2
# Gelof, Zack                 24  497             0.632               89.2
# Schuemann, Max              27  396             0.619               89.0
# Garcia, Maikel              24  575             0.613               90.4
#
#                     sprint_speed  Cluster
# name
# Judge, Aaron                26.8        3
# Ohtani, Shohei              28.1        3
# Tucker, Kyle                26.0        3
# Soto, Juan                  26.8        3
# Witt Jr., Bobby             30.5        3
# ...                          ...      ...
# Bailey, Patrick             25.2        3
# Morel, Christopher          27.3        3
# Gelof, Zack                 28.7        3
# Schuemann, Max              27.8        3
# Garcia, Maikel              27.9        3
#
# [149 rows x 6 columns]
